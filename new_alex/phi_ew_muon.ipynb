# %%
import numpy as np
import matplotlib.pyplot as plt


import math
import csv
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

import matplotlib as mpl
import seaborn as sns
 

#matplotlib.verbose.level = 'debug-annoying'
mpl.rcParams.update({'font.size': 16})
import sys
import os

sns.set_theme()
palette = sns.color_palette('colorblind')
sns.set_context("paper")
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
#sns.set(font_scale=1.5, rc={'text.usetex' : True})

# %%
muon_angles_deg = np.asarray([0,
32.8877774405093,
89.9543738355392,
151.833815709668,
180,
208.166184290332,
270.045626164461,
327.112222559491,
])

muon_angles = np.asarray([0,
0.574,
1.57,
2.65,
3.14159265358979,
3.63318530717959,
4.71318530717959,
5.70918530717959
])

# %%
phi_ew_mean = np.asarray([-65.58,
-100.81,
-92.84,
-76.65,
-20.49,
-11.84,
-12.2,
-19.34,
])*2*np.pi/360

phi_ew_mean_deg_ref4 = np.asarray([158.44,
122.53,
130.24,
144.25,
-155.49,
-142.88,
-146.86,
-153.32
])

phi_ew_err_ref4_deg = np.asarray([2.37,
1.85,
0.74,
2.09,
1.45,
1.36,
0.54,
1.4])

phi_ew_mean_ref4 = np.asarray([158.44,
122.53,
130.24,
144.25,
-155.49,
-142.88,
-146.86,
-153.32
])*2*np.pi/360

phi_ew_ref4_err = np.asarray([2.37,
1.85,
0.74,
2.09,
1.45,
1.36,
0.54,
1.4])*2*np.pi/360


phi_ew_err = np.asarray([2.06,
1.55,
0.63,
1.73,
1.24,
2.46,
0.7,
2.18,
])*2*np.pi/360

phi_ew_mean_deg = np.asarray([-65.58,
-100.81,
-92.84,
-76.65,
-20.49,
-11.84,
-12.2,
-19.34,
])

phi_ew_err_deg = np.asarray([2.06,
1.55,
0.63,
1.73,
1.24,
2.46,
0.7,
2.18,
])

# %%
fig = plt.figure(figsize=(8,4))
plt.errorbar(muon_angles_deg, phi_ew_mean_deg_ref4, yerr=phi_ew_err_ref4_deg, linestyle='None', color="green")
plt.scatter(muon_angles_deg, phi_ew_mean_deg_ref4, marker=".", color="black")
plt.title("Phi_ew vs Phi_muon")
plt.xlabel("Phi_muon (deg.)")
plt.ylabel("Phi_ew_mean (deg.)")
# Out:
# Text(0, 0.5, 'Phi_ew_mean (deg.)')

# %%
# #ref channel 1
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='polar')
fig2 = plt.figure(figsize=(4,4))
ax2 = fig2.add_subplot(111)
ones = np.ones(len(muon_angles))
filled_markers = ('o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
positions = ["C2", "L2", "L0", "L1", "C1", "R1", "R0", "R2"]
x = [1, 1, 0, -1, -1, -1, 0, 1]
y = [0, 1, 1, 1, 0, -1, -1, -1]
ax.set_rorigin(-1)
ax.scatter(0, "", color="white")
for i in range(len(muon_angles)):
  ax.errorbar([ phi_ew_mean[i], muon_angles[i]], ["Phi_ew", "Phi_muon"], xerr=[phi_ew_err[i], 0], markersize=10, alpha=0.8, linestyle='None', color="black")
  ax.scatter([ phi_ew_mean[i], muon_angles[i]], ["Phi_ew", "Phi_muon"], label = positions[i], marker=filled_markers[i], s=100, alpha=0.8, linestyle='None')
  ax2.scatter(x[i], y[i],  marker=filled_markers[i], label = positions[i], s=100, alpha=0.8, linestyle='None')
ax.legend(loc="center right", bbox_to_anchor=(0.7, 0.2, 0.5, 0.5))
ax2.set_xlabel("Window")
ax2.set_title("Locations of measurements")
ax.set_title("Phi_muon with respective Phi_ew, phi_ew not in absolute position!")
ax2.legend(loc="center right", bbox_to_anchor=(0.8, 0.2, 0.5, 0.5))
plt.show()

# %%
#ref channel 4
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='polar')
fig2 = plt.figure(figsize=(4,4))
ax2 = fig2.add_subplot(111)
ones = np.ones(len(muon_angles))
filled_markers = ('o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
positions = ["C2", "L2", "L0", "L1", "C1", "R1", "R0", "R2"]
x = [1, 1, 0, -1, -1, -1, 0, 1]
y = [0, 1, 1, 1, 0, -1, -1, -1]
ax.set_rorigin(-1)
ax.scatter(0, "", color="white")
for i in range(len(muon_angles)):
  ax.errorbar([ phi_ew_mean_ref4[i], muon_angles[i]], ["Phi_ew", "Phi_muon"], xerr=[phi_ew_ref4_err[i], 0], markersize=10, alpha=0.8, linestyle='None', color="black")
  ax.scatter([ phi_ew_mean_ref4[i], muon_angles[i]], ["Phi_ew", "Phi_muon"], label = positions[i], marker=filled_markers[i], s=100, alpha=0.8, linestyle='None')
  ax2.scatter(x[i], y[i],  marker=filled_markers[i], label = positions[i], s=100, alpha=0.8, linestyle='None')
ax.legend(loc="center right", bbox_to_anchor=(0.7, 0.2, 0.5, 0.5))
ax2.set_xlabel("Window")
ax2.set_title("Locations of measurements")
ax.set_title("Phi_muon with respective Phi_ew, phi_ew not in absolute position!")
ax2.legend(loc="center right", bbox_to_anchor=(0.8, 0.2, 0.5, 0.5))
plt.show()

# %%
phi_ew_ref0 = np.asarray([-21.07,
-57.15,
-49.37,
-35.89,
24.5,
37.03,
33.14,
26.52
])

phi_ew_err_ref0 = np.asarray([1.95,
1.76,
0.67,
1.85,
1.28,
1.22,
0.5,
1.26
])

# %%
#ref channel 0
fig = plt.figure(figsize=(8,4))
plt.errorbar(muon_angles_deg, phi_ew_ref0, yerr=phi_ew_err_ref0, linestyle='None', color="green")
plt.scatter(muon_angles_deg, phi_ew_ref0, marker=".", color="black")
plt.title("Phi_ew vs Phi_muon")
plt.xlabel("Phi_muon (deg.)")
plt.ylabel("Phi_ew_mean (deg.)")
# Out:
# Text(0, 0.5, 'Phi_ew_mean (deg.)')

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='polar')
fig2 = plt.figure(figsize=(4,4))
ax2 = fig2.add_subplot(111)
ones = np.ones(len(muon_angles))
filled_markers = ('o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
positions = ["C2", "L2", "L0", "L1", "C1", "R1", "R0", "R2"]
x = [1, 1, 0, -1, -1, -1, 0, 1]
y = [0, 1, 1, 1, 0, -1, -1, -1]
ax.set_rorigin(-1)
ax.scatter(0, "", marker='None', linestyle='None')
ax.scatter(0, 1.2, marker='None', linestyle='None')
for i in range(len(muon_angles)):
  ax.errorbar([ phi_ew_ref0[i]*2*np.pi/360], [1], xerr=[phi_ew_err_ref0[i]*2*np.pi/360], markersize=8, alpha=0.6, linestyle='None', color='black', marker='None')
  ax.scatter([ phi_ew_ref0[i]*2*np.pi/360], [1], label = positions[i], marker=filled_markers[i], s=100, alpha=1, linestyle='None', color=palette[i])
for i in range(len(muon_angles)): 
  ax2.scatter(x[i], y[i],  marker=filled_markers[i], label = positions[i], s=100, alpha=1, linestyle='None', color=palette[i])
ax.legend(loc="center right", bbox_to_anchor=(0.7, 0.2, 0.5, 0.5))
ax2.set_xlabel("Window")
ax2.set_title("Approximate locations of measurements on detector box (arbitrary units)")
ax.set_title("\Phi_{ew}")
ax2.legend(loc="center right", bbox_to_anchor=(0.9, 0.2, 0.5, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\projections\polar.py in draw(self, renderer, *args, **kwargs)
#     993             self.yaxis.set_clip_path(self.patch)
#     994
# --> 995         Axes.draw(self, renderer, *args, **kwargs)
#     996
#     997     def _gen_axes_patch(self):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2746             renderer.stop_rasterizing()
#    2747
# -> 2748         mimage._draw_list_compositing_images(renderer, self, artists)
#    2749
#    2750         renderer.close_group('axes')
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     929     def draw(self, renderer):
#     930         self.set_sizes(self._sizes, self.figure.dpi)
# --> 931         Collection.draw(self, renderer)
#     932
#     933
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     383             else:
#     384                 combined_transform = transform
# --> 385             extents = paths[0].get_extents(combined_transform)
#     386             if (extents.width < self.figure.bbox.width
#     387                     and extents.height < self.figure.bbox.height):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\path.py in get_extents(self, transform, **kwargs)
#     601                 xys.append(curve([0, *dzeros, 1]))
#     602             xys = np.concatenate(xys)
# --> 603         return Bbox([xys.min(axis=0), xys.max(axis=0)])
#     604
#     605     def intersects_path(self, other, filled=True):
#
# ~\anaconda3\envs\test\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      41 def _amin(a, axis=None, out=None, keepdims=False,
#      42           initial=_NoValue, where=True):
# ---> 43     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      44
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity
